# %% [markdown]
# # NuScenes Dataset
#
# ## This notebook is for the analysis of the NuScenes-mini dataset.

# %%
import json
import os
PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), "..", ".."))
os.chdir(PROJECT_ROOT)

nuscenes_data_file = "resources/output/nusciences_processed.json"
with open(nuscenes_data_file, "r") as file:
    nuscenes_dataset = json.load(file)

    from src.analysis.analyze_nucenes import AnalyzeNuscenes
analyze_scenes = AnalyzeNuscenes(nuscenes_dataset=nuscenes_dataset)

# %% [markdown]
# ### Speed
#
# We plot the speed distribution of the samples in MPH.
#
# What we see is that most of the scenes are standalone as they have relative speeds of 0.

# %%
analyze_scenes.plot_speed()

# %% [markdown]
# ### Object Distribution
#
# We now attempt to plot ojects that every image contains. This is present as the metadata for an image.
#
# #### Observation
#
# We observe that most of the items detected in the image are Pedestrians, Barriers and Cars, which is an expected result.
#
# What is surprising is that we do not see many motorcycles, which might allude to the fact that they aren't popular where the images were taken.

# %%
analyze_scenes.plot_object_distributions()
